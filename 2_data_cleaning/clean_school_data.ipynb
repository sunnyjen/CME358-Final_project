# %%
import pandas as pd
from pathlib import Path
current_dir = Path.cwd().parent
school_osslt = pd.read_csv(current_dir/"data"/"csv"/"2021_OSSLT.csv")
school_osslt
# Out:
#                                     School Name Unnamed: 1  Unnamed: 2  \
# 0                                           NaN        NaN         NaN
# 1                                           NaN        NaN         NaN
# 2                                           NaN        NaN         NaN
# 3                                           NaN        NaN         NaN
# 4                                           NaN        NaN         NaN
# 5                                           NaN   Province         NaN
# 6                                           NaN       TDSB         NaN
# 7                  A Y Jackson Secondary School        NaN         NaN
# 8                Agincourt Collegiate Institute        NaN         NaN
# 9          Albert Campbell Collegiate Institute        NaN         NaN
# 10            ALPHA II Alternative School (Sec)        NaN         NaN
# 11          Alternative Scarborough Education 1        NaN         NaN
# ...

# %% [markdown]
# Now there are a lot of duplicates...

# %%
df_cleaned = school_osslt.dropna(how='all')
df_cleaned
# Out:
#                                     School Name Unnamed: 1  Unnamed: 2  \
# 0                                           NaN        NaN         NaN
# 1                                           NaN        NaN         NaN
# 2                                           NaN        NaN         NaN
# 3                                           NaN        NaN         NaN
# 4                                           NaN        NaN         NaN
# 5                                           NaN   Province         NaN
# 6                                           NaN       TDSB         NaN
# 7                  A Y Jackson Secondary School        NaN         NaN
# 8                Agincourt Collegiate Institute        NaN         NaN
# 9          Albert Campbell Collegiate Institute        NaN         NaN
# 10            ALPHA II Alternative School (Sec)        NaN         NaN
# 11          Alternative Scarborough Education 1        NaN         NaN
# ...
